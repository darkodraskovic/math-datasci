# %% [markdown]
# ## Standard imports

# %%
import math

import numpy as np
import pandas as pd
from numpy.random import randn
import numpy.random as rnd

import scipy as sp
from scipy import stats
from scipy import special

import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)

import seaborn as sns
from bokeh.plotting import figure, show

import sympy as sym
import sympy.plotting.plot as symplot

from IPython.display import display, Math
sym.init_printing()

x,y,z = sym.symbols('x,y,z')
a,b,c,d,e,f,g,h = sym.symbols('a,b,c,d,e,f,g,h')

# %% [markdown]
# ## Computing limits of a function

# %%
fx = x**3
lim_pt = 1.5
lim = sym.limit(fx, x, lim_pt)

display(Math('\\lim_{x\\to %g} %s = %g'%(lim_pt, sym.latex(fx), lim)))

fxx = sym.lambdify(x, fx)
xx = np.linspace(-5,5,200)

fig, ax = plt.subplots()
ax.plot(xx, fxx(xx))
ax.plot(lim_pt, lim, 'ro')
fig.show()
# Out:
# $\displaystyle \lim_{x\to 1.5} x^{3} = 3.375$

# %%
fx = x**2 / (x-2)
lim_pt = 2
lim = sym.limit(fx, x, lim_pt, dir='-')
display(lim)

display(Math('\\lim_{x\\to %g^-} %s = %g'%(lim_pt, sym.latex(fx), lim)))

fxx = sym.lambdify(x, fx)
xx = np.linspace(1,3,102)

fig, ax = plt.subplots()
ax.plot(xx, fxx(xx))
ax.plot(lim_pt, lim, 'ro')
# Out:
# -∞
# $\displaystyle \lim_{x\to 2^-} \frac{x^{2}}{x - 2} = -inf$

# %% [markdown]
# ### Division of limits = limit of division

# %%
fx = sym.exp(-x)*sym.sqrt(x+1)
fxx = sym.lambdify(x, fx)
xx = np.linspace(-1,10,124)

fig, ax = plt.subplots()
ax.plot(xx, fxx(xx))
fig.show()

# %%
gx = sym.cos(x + sym.sin(x))
gxx = sym.lambdify(x, gx)
xx = np.linspace(-10,10,124)

fig, ax = plt.subplots()
ax.plot(xx, gxx(xx))
fig.show()

# %%
f_div_g = fx / gx
# display(f_div_g)

lim_pt = 3
limf = sym.limit(fx,x,lim_pt)
limg = sym.limit(gx,x,lim_pt)
display(Math('\\lim_{x\\to %g} %s = %s'%(lim_pt, sym.latex(fx), sym.latex(limf))))
display(Math('\\lim_{x\\to %g} %s = %s'%(lim_pt, sym.latex(gx), sym.latex(limg))))

# division of limits
display(Math('\\frac{\\lim_{x\\to %g} %s}{lim_{x\\to %g} %s} = %g'
             %(lim_pt, sym.latex(fx), lim_pt, sym.latex(gx), limf/limg)))

# limit of division
limfg = sym.limit(f_div_g, x, 3)
display(Math('\\lim_{x\\to %g} %s = %g'%(lim_pt, sym.latex(f_div_g), limfg)))
# Out:
# $\displaystyle \lim_{x\to 3} \sqrt{x + 1} e^{- x} = \frac{2}{e^{3}}$
# $\displaystyle \lim_{x\to 3} \cos{\left(x + \sin{\left(x \right)} \right)} = \cos{\left(\sin{\left(3 \right)} + 3 \right)}$
# $\displaystyle \frac{\lim_{x\to 3} \sqrt{x + 1} e^{- x}}{lim_{x\to 3} \cos{\left(x + \sin{\left(x \right)} \right)}} = -0.0995741$
# $\displaystyle \lim_{x\to 3} \frac{\sqrt{x + 1} e^{- x}}{\cos{\left(x + \sin{\left(x \right)} \right)}} = -0.0995741$

# %% [markdown]
# # Lore ipsum

# %% [markdown]
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed ut consectetur massa. Etiam malesuada ac libero et rhoncus. Pellentesque vel nulla sit amet turpis vehicula efficitur. Vivamus cursus elit quam, sollicitudin venenatis lectus porta in. Praesent tempus nunc in mi sollicitudin volutpat. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Maecenas lacus diam, ultrices at mauris eu, blandit maximus mauris. Quisque sagittis, lorem quis ornare scelerisque, turpis sem gravida purus, ut aliquet sapien mi eget felis. Ut tristique tempor bibendum. In nec arcu sed leo commodo imperdiet. Nam ac lacus elit. Vivamus efficitur urna nec dolor aliquet bibendum. Nunc scelerisque, justo ac suscipit vestibulum, lacus urna pharetra elit, vitae semper ipsum lacus quis neque. Nulla nec sem dapibus, egestas lorem eget, ultrices augue. Proin ullamcorper velit enim, vitae laoreet orci tristique sit amet. Donec sit amet odio orci.
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Sed ut consectetur massa. Etiam malesuada ac libero et rhoncus. Pellentesque vel nulla sit amet turpis vehicula efficitur. Vivamus cursus elit quam, sollicitudin venenatis lectus porta in. Praesent tempus nunc in mi sollicitudin volutpat. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Maecenas lacus diam, ultrices at mauris eu, blandit maximus mauris. Quisque sagittis, lorem quis ornare scelerisque, turpis sem gravida purus, ut aliquet sapien mi eget felis. Ut tristique tempor bibendum. In nec arcu sed leo commodo imperdiet. Nam ac lacus elit. Vivamus efficitur urna nec dolor aliquet bibendum. Nunc scelerisque, justo ac suscipit vestibulum, lacus urna pharetra elit, vitae semper ipsum lacus quis neque. Nulla nec sem dapibus, egestas lorem eget, ultrices augue. Proin ullamcorper velit enim, vitae laoreet orci tristique sit amet. Donec sit amet odio orci.
